# %% [markdown]
# **Lista 4**

# %% [markdown]
# Torre de Hanói é um quebra-cabeça que consiste em uma base contendo três pinos, em um dos quais são dispostos alguns discos uns sobre os outros, em ordem crescente de diâmetro, de cima para baixo. O problema consiste em passar todos os discos de um pino para outro qualquer, usando um dos pinos como auxiliar, de maneira que um disco maior nunca fique em cima de outro menor em nenhuma situação.
#
# ![torre_hanoi.png](data:image/png;base64,...)

# %% [markdown]
# Questão 1 ) Implemente um programa que solucione a Torre de Hanoi para 3 pinos e n Discos

# %%
def hanoi_tour(iter, orig, dest, auxiliar):
  #Defina o passo base
  if ...:
    ...
  else:
    #Defina a recursão
    ...
#Chame a função para avaliar se está correta
hanoi_tour(...)
# Out:
# Mova o disco 1 de A para B
# Mova o disco 2 de A para C
# Mova o disco 1 de B para C
# Mova o disco 3 de A para B
# Mova o disco 1 de C para A
# Mova o disco 2 de C para B
# Mova o disco 1 de A para B

# %% [markdown]
# **Lista 5**

# %% [markdown]
# Questão 2 ) Dada uma matriz e um número, crie uma função que retorne a posição deste número na matriz e quantas vezes ele aparece naquela posição. Exemplo:
#
# matriz = [[0,1,1], [ 4, 6 , 1]]
#
# numero_buscar = 1
#
# [(1, 2), (2, 1)]

# %%
#Defina sua funcao com parametros de entrada coerentes
def busca_matriz(...):
  #Crie uma lista auxiliar e crie uma iteração para buscar as informacoes desejadas
  ...
  for ...:
    #Guarde as informações que está buscando
    ...
  return ...

#Defina a matriz
busca_matriz(...)
# Out:
# [(1, 2), (2, 1)]

# %% [markdown]
# Questão 3) Crie uma classe que receba uma matriz de entrada, denominada operaMatriz, e execute as operações a seguir:
#
# a) Acesse uma posição da matriz e retorne o valor correspondente.
#
# b) Dada uma matriz e um número, retorne os pares de índice ("linha", "coluna") em que aquele número se encontra na matriz.
#
#   Atenção: a função index presente em listas nao será suficiente, pois retorna apenas a primeira ocorrência encontrada. Utilize a função enumerate para criar uma função em sua classe que auxilie na busca de todos os indices.
#
# c) Acesse uma posição da matriz e substitua o valor presente naquela posição.
#
# d) Defina a função f(x) = x**2, acrescente-a à classe com o nome função custo. Crie também uma função que dada uma posição na matriz, cálcule o valor da função custo para aquela posiçao na matriz e substitua o valor pregresso.

# %% [markdown]
# Letra A) Acesse uma posição da matriz e retorne o valor correspondente.

# %%
#Crie sua classe
#Sugestao: crie uma classe por letra e vá adicionando as informações pedidas à medida que novas exigências surgem
class operaMatriz_letra_a:

  def __init__(...):
    #Inicialize sua classe com os parametros necessários

  #Crie a função que realiza a operação que retorna o valor dadas as posições
  def busca_matriz(...):
    return ...

#Chame sua classe e atribua seu valor a uma variável
oper_mm = ...

#Chame a função pedida na questão
oper_mm.busca_matriz(...)
# Out:
# 6

# %% [markdown]
# Letra B) Dada uma matriz e um número, retorne os pares de índice ("linha", "coluna") em que aquele número se encontra na matriz.

# %%
#Crie sua classe, aproveitando o progresso feito na letra a
class operaMatriz_letra_b:

  def __init__(...):
    #Inicialize sua classe
  
  #Crie a função que realiza a operação que retorna o valor dadas as posições
  def busca_matriz(...):
    return ...
    
  #Crie uma função auxiliar que encontre os indices em cada linha da sua matriz. A função index só retorna o prineiro elemento encontrado, o que impossibilita sua utilização
  def encontra_indices(...):
    return ...

  #Crie a função pedida no enunciado
  def busca_idx_matriz(...):
    #Crie uma lista auxiliar para lhe ajudar a guardar as informaçoes e defina a iteração que realizará a busca das informações pedidas
    # e por fim retorne as informações levantadas na sua iteração
    ...
    for ...:
      ...
    return ...

#Chame sua classe e guarde-a em uma variável
oper_mm = ...

#Aplique a função criada e avalie as saídas
oper_mm.busca_idx_matriz(...)
# Out:
# [(0, [2]), (1, [2])]

# %% [markdown]
# Letra C) Acesse uma posição da matriz e substitua o valor presente naquela posição.

# %%
class operaMatriz_letra_c:

  def __init__(...):
    #Inicialize sua classe
  
  #Crie a função que realiza a operação que retorna o valor dadas as posições
  def busca_matriz(...):
    return ...
    
  #Crie uma função auxiliar que encontre os indices em cada linha da sua matriz. A função index só retorna o prineiro elemento encontrado, o que impossibilita sua utilização
  def encontra_indices(...):
    return ...

  #Crie a função pedida no enunciado
  def busca_idx_matriz(...):
    #Crie uma lista auxiliar para lhe ajudar a guardar as informaçoes e defina a iteração que realizará a busca das informações pedidas
    # e por fim retorne as informações levantadas na sua iteração
    ...
    for ...:
      ...
    return ...
  
  #Crie a função que seja capaz de substituir um valor na matriz dadas as posições
  def subst_matriz(...):
    ...
    return ...

#Chame sua classe e guarde-a em uma variável
oper_mm = ...

#Aplique a função criada e avalie as saídas
oper_mm.subst_matriz(...)
# Out:
# [[0, 5, 1], [4, 6, 1]]

# %% [markdown]
# Letra D) Defina a função f(x) = x**2, acrescente-a à classe com o nome função custo. Crie também uma função que dada uma posição na matriz, cálcule o valor da função custo para aquela posiçao na matriz e substitua o valor pregresso.

# %%
class operaMatriz_letra_d:

  def __init__(...):
    #Inicialize sua classe
  
  #Crie a função que realiza a operação que retorna o valor dadas as posições
  def busca_matriz(...):
    return ...
    
  #Crie uma função auxiliar que encontre os indices em cada linha da sua matriz. A função index só retorna o prineiro elemento encontrado, o que impossibilita sua utilização
  def encontra_indices(...):
    return ...

  #Crie a função pedida no enunciado
  def busca_idx_matriz(...):
    #Crie uma lista auxiliar para lhe ajudar a guardar as informaçoes e defina a iteração que realizará a busca das informações pedidas
    # e por fim retorne as informações levantadas na sua iteração
    ...
    for ...:
      ...
    return ...
  
  #Crie a função que seja capaz de substituir um valor na matriz dadas as posições
  def subst_matriz(...):
    ...
    return ...
  
  #Definindo função custo
  def custo(...):
    return ...

  def subst_custo_matriz(...):
    #Utilize sua função para buscar um determinado valor dada uma posição
    ...
    #Calcule o valor da função custo dado o número encontrado
    ...
    #Utilize a função para substituir o valor em uma matriz já definida no exercício anterior
    return ...

#Chame sua classe e guarde-a em uma variável
oper_mm = ...

#Aplique a função criada e avalie as saídas
oper_mm.subst_custo_matriz(...)
# Out:
# [[0, 5, 1], [4, 36, 1]]

# %%
matriz
# Out:
# [[0, 5, 1], [4, 6, 1]]

# %% [markdown]
# Questao 4) Suponha que você tenha uma matriz nxn em que cada posição há a valência de uma determinada máquina. A partir daí, crie uma classe receba uma matriz de entrada e opere as seguintes contas:
#
# a) Seja capaz de selecionar a valência de determinada máquina dados os índices de entrada.
#
#
# b) Seja capaz de calcular uma matriz de saída com valores de aptidão calculados pela função J(x) = xˆ2 - (0.3*cos((10*pi)*x)), onde x é valor da matriz de entrada de valências.
#
# Dica: Importe a bilbioteca numpy para ajudar com as funções trigonométricas
#
# c) considere a matriz [[61, 35, 21, 44, 82], [11, 38, 52, 50, 31], [26, 1, 90, 52, 0]] e opere as letras A e B na sua classe.

# %% [markdown]
# Letra A) Seja capaz de selecionar a valência de determinada máquina dados os índices de entrada.

# %%
class matrizMaquinas:

  def __init__(...):
    #Inicialize sua classe
    ...
  
  #Parametrize sua função e faça as operações necessárias para atender o enunciado
  def busca_valencia(...):
    return ...
# Out:
# 35

# %% [markdown]
# Letra B ) Seja capaz de calcular uma matriz de saída com valores de aptidão calculados pela função J(x) = xˆ2 - (0.3*cos((10*pi)*x)), onde x é valor da matriz de entrada de valências.

# %%
import numpy as np
#Aproveite o progesso feito na letra A
class matrizMaquinas:

  def __init__(...):
    #Inicialise sua classe
    ...

  #Aproveite o progresso realizado na classe anterior
  def busca_valencia(...):
    return ...
  
  #Defina a função aptidão das maquinas. Utilize a biblioteca numpy para te ajudar.
  def aptidao_maquina(...):
    return ...

# %% [markdown]
# Letra C) Considere a matriz [[61, 35, 21, 44, 82], [11, 38, 52, 50, 31], [26, 1, 90, 52, 0]] e opere as letras A e B na sua classe.

# %%
#Defina a matriz que será utilizada para avaliar as letras anteriores
matriz_maquinas = ...

# %%
maquinas = matrizMaquinas()

#C - Avaliacao da letra A
#Chame a função busca valencia a partir da matriz já definida
maquinas.busca_valencia(...)
# Out:
# 35

# %%
#C - Avaliacao da letra B
#Chame a função aptidão maquina a partir da matriz já definida
maquinas.aptidao_maquina(...)
# Out:
# array([[ 3.7207e+03,  1.2247e+03,  4.4070e+02,  1.9357e+03,  6.7237e+03],
#        [ 1.2070e+02,  1.4437e+03,  2.7037e+03,  2.4997e+03,  9.6070e+02],
#        [ 6.7570e+02,  7.0000e-01,  8.0997e+03,  2.7037e+03, -3.0000e-01]])

# %%
#tirando a prova real de C-B calculando a função na mão para o primeiro elemento da matriz

61 ** 2 - (0.3 * np.cos((10* np.pi)* 61))
# Out:
# 3720.7
